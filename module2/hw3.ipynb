# %% [markdown]
# # Домашнее задание 3. Тестирование.

# %% [markdown]
# Дедлайн: 12.03.2019 23:59

# %% [markdown]
# Вам нужно написать программу, для имитации флеш-карточек для запоминания английских слов и юнит-тесты для нее.
# Пример использования:
# ```
# >>> from flash_cards import FlashCards
# >>> fc = FlashCards(<path_to_input_file.json>)
# >>> fc.words
# ['яблоко', 'хурма']
# >>>> fc.play()
# яблоко
# apple
# хурма
# tomato
# Done! 1 of 2 words correct.
#
#
# >>> fc.add_word('груша', 'pear')
# >>> fc.words
# ['яблоко', 'хурма', 'груша']
# Succesfully added word 'груша'.
# >>> fc.add_word('груша', 'pear')
# 'груша' already in dictionary.
#
#
# >>> fc.delete_word('хурма')
# Succesfully deleted word 'хурма'.
# >>> fc.words
# ['яблоко', 'груша']
# >>> fc.delete_word('хурма')
# 'хурма' not in dictionary.
#
#
# >>> fc.delete_word('яблоко')
# Succesfully deleted word 'яблоко'.
# >>> fc.delete_word('груша')
# Succesfully deleted word 'груша'.
# >>> fc.words
# []
# >>>> fc.play()
# Dicionary is empty!
#
# ```

# %% [markdown]
# Примерная структура класса:

# %%
class FlashCards():
    def __init__(self, path_to_file: str):
        '''
        Прочитает пары слов из указанного файла в формате json. 
        Создаст все требующиеся атрибуты.  
        '''
        pass

    def play(self) -> str:
        '''
        Выдает русские слова из словаря в рандомном порядке, 
        сверяет введенный пользователем перевод с правильным 
        (регистр введенного слова при этом не важен), 
        пока слова в словаре не закончатся. 
        Возвращает строку с количеством правильных ответов/общим количеством 
        слов в словаре (см пример работы). 
        '''

    def add_word(self, russian: str, english: str) -> str:
        '''
        Добавляет в словарь новую пару слов, 
        если русского слова еще нет в словаре.
        Возвращает строку в зависимоти от результата (см пример работы). 
        '''

    def delete_word(self, russian: str) -> str:
        '''
        Удаляет из словаря введенное русское слово
        и соответсвующее ему английское. 
        Возвращает строку в зависимоти от результата (см пример работы). 
        '''

# %% [markdown]
# + Только одно направление перевода: с русского на английский, русские слова в словаре уникальны, английские - не обязательно.
# + Программа не должна вылетать с ошибкой вне засисимости от того, что попытаеся сделать пользователь (передать в метод аргумент неправильного типа, удалить слово которого нет в словаре, вручную поменять значение каких-то атрибутов)
# + У пользователя не должно быть доступа к английским словам через экземпляр класса ни в каком виде, список русских слов должно быть можно посмотреть, но не изменить. Все другие используемые вами для работы программы атрибуты должно быть нельзя ни посмотреть, ни изменить (чтобы пользователь не увидел лишнего и ничего не сломал).
# + Должны быть протестированы все логические части кода (нужны тесты на каждый вариант развития событий внутри метода.)
# + Вам нужно будет самостоятельно разобраться, как при тестировании обходиться с
#     - пользоательским вводом
#     - рандомом
#
# Это несложно нагуглить. Вероятнее всего удобно будет использовать встроенный модуль ***unittest.mock***.
#
# **Гарантировано, что**
# + в конструктор всегда будет передаваться строка, содержащая правильный путь до существующего валидного файла, в котором все правильно. (То есть его тестировать не нужно). Содержимое файла всегда будет в таком формате:
# ```
# {
# 	"яблоко": "apple",
# 	"хурма": "persimmon"
# }
# ```
# + пользователь не будет лазать в защищенные атрибуты
# + пользователь печатает только символы английской раскладки, кодировка точно не сломается
#
# **Структура дз**:
# + дз нужно залить в репозиторий в отдельной папке
# + тесты должны быть написаны в отдельном файле (если нужно, то в нескольких файлах), файл(ы) должен лежать в папке tests внутри папки с дз
# ```
# ├── hw3
#    ├── flash_cards
#    │   ├── flash_cards.py
#    │   ├── ...
#    └── tests
#        ├── ...
# ```
