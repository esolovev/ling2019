# %% [markdown]
# ## Домашнее задание 6
#
# Дедлайн: 1 июня 2020 23:59
#
# В этом задании требуется реализовать инструмент для нахождения кратчайшего пути от одной статьи в русской Википедии до другой.
#
# За это задание можно получить максимум 13 баллов.

# %% [markdown]
# ## Часть 1 (1 балл)

# %% [markdown]
# Ниже приведена функция, принимающая на вход HTML-код страницы Википедии и отдающая все ссылки на другие статьи из русской Википедии, содержащиеся в этом коде.
#
# У этой функции есть как минимум два недостатка:
#
# * Если мы возьмем результат работы этой функции и отберем только уникальные ссылки, у нас может произойти ситуация, когда в нашем множестве ссылок есть как ссылка вида `/wiki/какая-то_статья`, так и `/wiki/какая-то_статья#какой-то_подраздел` (хотя на самом деле это одна и та же статья).
# * Эта функция отдает ссылки не только на статьи, но и на служебные страницы (`/wiki/Служебная:Свежие_правки`) и, например, файлы (`/wiki/Файл:Calabi_yau_formatted.svg`). Эти ссылки нам не нужны.
#
# Доработайте функцию, исправив перечисленные недостатки.

# %%
from bs4 import BeautifulSoup # pip install bs4
from typing import List
import requests # pip install requests
import urllib

def links_from_text(text):
    soup = BeautifulSoup(text)
    content = soup.find("div", {"id": "mw-content-text"})
    
    links = content.find_all("a")
    
    for link in links:
        href = link.get('href', '')
        
        if href.startswith('/wiki'): 
            yield href 
            

start_url = 'https://ru.wikipedia.org/wiki/Теория струн'

for url in links_from_text(requests.get(start_url).text):
    print(urllib.parse.unquote(url))
# Out:
# /wiki/Файл:Calabi_yau_formatted.svg
# /wiki/Теория_суперструн
# /wiki/Теория_суперструн
# /wiki/Теория_бозонных_струн
# /wiki/М-теория
# /wiki/Гетеротическая_струна
# /wiki/Голографический_принцип
# /wiki/Квантовая_струна
# /wiki/Брана
# /wiki/Пространство_Калаби_—_Яу
# /wiki/D-брана
# /wiki/E₈_(математика)
# /wiki/Суперсимметрия
# /wiki/Супергравитация
# /wiki/Квантовая_гравитация
# /wiki/Виттен,_Эдвард
# /wiki/Венециано,_Габриеле
# /wiki/Грин,_Брайан_Рэндолф
# /wiki/Гросс,_Дейвид
# /wiki/Каку,_Митио
# /wiki/Малдасена,_Хуан
# /wiki/Поляков,_Александр_Маркович
# /wiki/Сасскинд,_Леонард
# /wiki/Шварц,_Джон_Генри
# /wiki/Портал:Физика
# /wiki/Теоретическая_физика
# /wiki/Элементарная_частица
# /wiki/Квантовая_струна
# /wiki/Квантовая_механика
# /wiki/Теория_относительности
# /wiki/Квантовая_гравитация
# /wiki/Файл:Point&string.svg
# /wiki/Файл:Point&string.svg
# /wiki/Диаграммы_Фейнмана
# /wiki/Стандартная_модель
# /wiki/Фундаментальные_взаимодействия
# /wiki/Квантовая_струна
# /wiki/Планковская_длина
# /wiki/Квантовая_теория_поля
# /wiki/Перенормировка_(метод)
# /wiki/Материя_(физика)
# /wiki/Пространство-время
# /wiki/1970-е
# /wiki/Габриэле_Венециано
# /wiki/Адрон
# /wiki/1980-е_годы
# /wiki/1990-е
# /wiki/Единая_теория
# /wiki/Теория_всего
# /wiki/Эйнштейн
# /wiki/Размерность_пространства
# /wiki/Компактификация
# /wiki/Пространство_Калаби_—_Яу
# /wiki/Орбифолд
# /wiki/Проблема_ландшафта
# /wiki/Научная_теория
# /wiki/Алгебраическая_геометрия
# /wiki/Дифференциальная_геометрия
# /wiki/Топология
# /wiki/Квантовая_гравитация
# /wiki/Большой_адронный_коллайдер
# /wiki/Файл:String_theory.svg
# /wiki/Файл:String_theory.svg
# /wiki/Протон
# /wiki/Нейтрон
# /wiki/Электрон
# /wiki/Кварк
# /wiki/Экстраполяция
# /wiki/Квантовая_струна
# /wiki/E=mc²
# /wiki/Масса
# /wiki/Пространство-время
# /wiki/Компактификация
# /wiki/Планковская_длина
# /wiki/Мультивселенная
# /wiki/Энергия
# /wiki/Эксперимент
# /wiki/Вторичное_квантование
# /wiki/Функционал
# /wiki/Пространство_петель
# /wiki/Квантовая_теория_поля
# /wiki/Суперсимметрия
# /wiki/Стандартная_модель
# /wiki/Стандартная_модель
# /wiki/Джон_Шварц
# /wiki/Суперсимметрия
# /wiki/Симметрия
# /wiki/М-теория
# /wiki/Файл:Leonard_Susskind_at_Stanford.jpg
# /wiki/Файл:Leonard_Susskind_at_Stanford.jpg
# /wiki/Леонард_Сасскинд
# /wiki/Квантовая_струна
# /wiki/Физика_элементарных_частиц
# /wiki/Адрон
# /wiki/Пион_(частица)
# /wiki/1960-е
# /wiki/Спин
# /wiki/Теория_Редже
# /wiki/Реджеон
# /wiki/Венециано,_Габриэле
# /wiki/Намбу,_Йоитиро
# /wiki/Леонард_Сасскинд
# /wiki/1968_год
# /wiki/Пи-мезон
# /wiki/Пион_(частица)
# /wiki/Амплитуда
# /wiki/Бета-функция
# /wiki/Эйлер,_Леонард
# /wiki/1730_год
# /wiki/Сумма_ряда
# /wiki/1970_год
# /wiki/Намбу,_Йоитиро
# /wiki/Квантовая_механика
# /wiki/Квантовая_струна_(физика)
# /wiki/Нота_(музыка)
# /wiki/Частота
# /wiki/Квантовая_хромодинамика
# /wiki/1974_год
# /wiki/Тахион
# /wiki/Скорость_света_в_вакууме
# /wiki/Принцип_причинности
# /wiki/Олив,_Дэвид
# /wiki/Джон_Шварц
# /wiki/Квантовая_струна
# /wiki/Квант
# /wiki/Гравитация
# /wiki/Гравитон
# /wiki/Теория_бозонных_струн
# /wiki/Действие_(механика)
# /wiki/Поляков,_Александр_Маркович
# /wiki/Масса
# /wiki/Спектр_масс
# /wiki/Бозон_(элементарная_частица)
# /wiki/Вселенная
# /wiki/Тахион
# /wiki/Фермион
# /wiki/Суперсимметрия
# /wiki/Теория_суперструн
# /wiki/Файл:Edward_Witten.jpg
# /wiki/Файл:Edward_Witten.jpg
# /wiki/Эдвард_Виттен
# /wiki/М-теория
# /wiki/Джон_Шварц
# /wiki/Файл:JuanMaldacena.jpg
# /wiki/Файл:JuanMaldacena.jpg
# /wiki/Малдасена,_Хуан
# /wiki/Гарвард
# /wiki/Эдвард_Виттен
# /wiki/Полчински,_Джозеф
# /wiki/М-теория
# /wiki/Брана
# /wiki/Малдасена,_Хуан
# /wiki/Суперсимметрия
# /wiki/Теория_Янга_—_Миллса
# /wiki/Голографический_принцип
# /wiki/Чёрная_дыра
# /wiki/Информация
# /wiki/Гравитация
# /wiki/Ландшафт_теории_струн
# /wiki/Ложный_вакуум
# /wiki/Космология
# /wiki/Кембриджский_университет
# /wiki/Аксион
# /wiki/Файл:Ambox_outdated_serious.svg
# /wiki/Гравитация
# /wiki/Квантовая_механика
# /wiki/Вселенная
# /wiki/Спин
# /wiki/Калибровочная_симметрия
# /wiki/Принцип_эквивалентности
# /wiki/Суперсимметрия
# /wiki/Стандартная_модель
# /wiki/Бозон_(элементарная_частица)
# /wiki/Фермион
# /wiki/Элементарная_частица
# /wiki/Скорость_света
# /wiki/Тахион
# /wiki/Суперсимметрия
# /wiki/Тахион
# /wiki/Суперсимметрия
# /wiki/Тахион
# /wiki/Фермион
# /wiki/Хиральность
# /wiki/Суперсимметрия
# /wiki/Тахион
# /wiki/Фермион
# /wiki/Хиральность
# /wiki/Суперсимметрия
# /wiki/Тахион
# /wiki/Суперсимметрия
# /wiki/Тахион
# /wiki/Квантовая_струна
# /wiki/Упругость
# /wiki/Квантовая_механика
# /wiki/Принцип_неопределённости_Гейзенберга
# /wiki/Ультрафиолетовая_расходимость
# /wiki/Квантовая_теория_поля
# /wiki/Регуляризация_(физика)
# /wiki/Суперсимметрия
# /wiki/М-теория
# /wiki/Дуальность
# /wiki/Классическая_теория_поля
# /wiki/Квантовая_теория_поля
# /wiki/Т-дуальность
# /wiki/S-дуальность
# /wiki/Квантовая_теория_поля
# /wiki/М-теория
# /wiki/Вакуум
# /wiki/Константа_связи
# /wiki/Теория_возмущений
# /wiki/М-теория
# /wiki/Топологическое_пространство
# /wiki/D-брана
# /wiki/Коммутатор_операторов
# /wiki/Вселенная
# /wiki/Уравнения_Максвелла
# /wiki/Общая_теория_относительности
# /wiki/Теория_относительности
# /wiki/Теодор_Калуца
# /wiki/1919_год
# /wiki/Оскар_Клейн
# /wiki/1926_год
# /wiki/Лоренц-инвариантность
# /wiki/Теория_бозонных_струн
# /wiki/Специальная_теория_относительности
# /wiki/Пространство-время
# /wiki/Файл:Calabi-Yau.png
# /wiki/Файл:Calabi-Yau.png
# /wiki/Пространство_Калаби_—_Яу
# /wiki/Mathematica
# /wiki/Компактификация
# /wiki/Пространство_Калаби_—_Яу
# /wiki/Мультивселенная
# /wiki/Брана
# /wiki/Гравитация
# /wiki/Гравитон
# /wiki/Чёрная_дыра
# /wiki/Критический_эксперимент
# /wiki/Критерий_Поппера
# /wiki/Уравнения_Максвелла
# /wiki/Ландшафт_теории_струн
# /wiki/Гугол
# /wiki/2005_год
# /wiki/Антропный_принцип
# /wiki/Квантовая_теория_поля
# /wiki/Теория_возмущений
# /wiki/Квантование_(физика)
# /wiki/Поляризация_электромагнитных_волн
# /wiki/Гамма-излучение
# /wiki/Гамма-всплеск
# /wiki/Световой_год
# /wiki/Планковская_длина
# /wiki/1996
# /wiki/Эндрю_Строминджер
# /wiki/Вафа,_Камран
# /wiki/Леонард_Сасскинд
# /wiki/Амартья_Сен
# /wiki/Энтропия
# /wiki/Бекенштейн,_Яаков
# /wiki/Стивен_Хокинг
# /wiki/Чёрная_дыра
# /wiki/Теория_возмущений
# /wiki/Чёрная_дыра
# /wiki/Брана
# /wiki/Масса
# /wiki/Электрический_заряд
# /wiki/Логарифм
# /wiki/Термодинамическая_система
# /wiki/Горизонт_событий
# /wiki/Энтропия
# /wiki/Кварк
# /wiki/Электрон
# /wiki/Глэшоу,_Шелдон_Ли
# /wiki/Нобелевская_премия
# /wiki/Теоретическая_физика
# /wiki/Космология
# /wiki/Венециано,_Габриэле
# /wiki/Инфляционная_модель_Вселенной
# /wiki/Скалярное_поле
# /wiki/Дилатон
# /wiki/Квант
# /wiki/Электромагнитное_поле
# /wiki/Безмассовые_частицы
# /wiki/Элементарная_частица
# /wiki/Вселенная
# /wiki/Космология
# /wiki/Вселенная
# /wiki/Большой_взрыв
# /wiki/Т-дуальность
# /wiki/Пространство-время
# /wiki/Суперсимметрия
# /wiki/10_сентября
# /wiki/2008_год
# /wiki/2010_год
# /wiki/Большой_адронный_коллайдер
# /wiki/Мультивселенная
# /wiki/Гравитация
# /wiki/Закон_всемирного_тяготения
# /wiki/Шифман,_Михаил_Аркадьевич
# /wiki/Гравитация
# /wiki/Электронвольт
# /wiki/Гравитон
# /wiki/Чёрная_дыра
# /wiki/Струна_(астрономия)
# /wiki/Гравитационная_линза
# /wiki/Гравитационная_волна
# /wiki/LIGO
# /wiki/VIRGO
# /wiki/Анизотропия
# /wiki/Реликтовое_излучение
# /wiki/Прохоров,_Александр_Михайлович
# /wiki/Физическая_энциклопедия
# /wiki/Советская_энциклопедия
# /wiki/Прохоров,_Александр_Михайлович
# /wiki/Физическая_энциклопедия
# /wiki/Советская_энциклопедия
# /wiki/Шварц,_Джон_Хенри
# /wiki/Международный_стандартный_серийный_номер
# /wiki/Морозов,_Алексей_Юрьевич
# /wiki/Успехи_физических_наук_(журнал)
# /wiki/1992_год
# /wiki/Мир_(издательство)
# /wiki/Служебная:Источники_книг/5030025189
# /wiki/Science
# /wiki/Doi
# /wiki/Атом
# /wiki/Земля
# /wiki/Проксима_Центавра
# /wiki/Солнце
# /wiki/ДНК
# /wiki/Мкм
# /wiki/Прохоров,_Александр_Михайлович
# /wiki/Физическая_энциклопедия
# /wiki/Советская_энциклопедия
# /wiki/Соросовский_образовательный_журнал
# /wiki/Астронет
# /wiki/Грин,_Брайан_Рэндолф
# /wiki/Элегантная_Вселенная._Суперструны,_скрытые_размерности_и_поиски_окончательной_теории
# /wiki/Служебная:Источники_книг/5484007844
# /wiki/Архив_Интернета#Проекты
# /wiki/Астронет
# /wiki/Участник:Igorivanov
# /wiki/Архив_Интернета#Проекты
# /wiki/Прохоров,_Александр_Михайлович
# /wiki/Физическая_энциклопедия
# /wiki/Советская_энциклопедия
# /wiki/Прохоров,_Александр_Михайлович
# /wiki/Физическая_энциклопедия
# /wiki/Советская_энциклопедия
# /wiki/Служебная:Источники_книг/9789812706140
# /wiki/Архив_Интернета#Проекты
# /wiki/Physical_Review
# /wiki/ArXiv.org
# /wiki/Лента._Ру
# /wiki/Фазовый_переход
# /wiki/Прохоров,_Александр_Михайлович
# /wiki/Физическая_энциклопедия
# /wiki/Советская_энциклопедия
# /wiki/Doi
# /wiki/Прохоров,_Александр_Михайлович
# /wiki/Физическая_энциклопедия
# /wiki/Советская_энциклопедия
# /wiki/Астронет
# /wiki/Успехи_физических_наук
# /wiki/Физический_институт_имени_П._Н._Лебедева_РАН
# /wiki/World_Scientific
# /wiki/Служебная:Источники_книг/9812566619
# /wiki/World_Scientific
# /wiki/Служебная:Источники_книг/9810235887
# /wiki/Springer_Science+Business_Media
# /wiki/Служебная:Источники_книг/0387978488
# /wiki/Логика_и_рост_научного_знания
# /wiki/Новая_газета
# /wiki/Сасскинд,_Леонард
# /wiki/ArXiv.org
# /wiki/ArXiv.org
# /wiki/Прохоров,_Александр_Михайлович
# /wiki/Физическая_энциклопедия
# /wiki/Советская_энциклопедия
# /wiki/Квантовая_гравитация
# /wiki/Планковская_длина
# /wiki/Европейское_космическое_агентство
# /wiki/Верлинде,_Эрик
# /wiki/Астронет
# /wiki/ArXiv.org
# /wiki/ArXiv.org
# /wiki/Астронет
# /wiki/Астронет
# /wiki/Вайнберг,_Стивен
# /wiki/Едиториал_УРСС
# /wiki/Служебная:Источники_книг/5354005264
# /wiki/Грин,_Брайан_Рэндолф
# /wiki/Элегантная_Вселенная._Суперструны,_скрытые_размерности_и_поиски_окончательной_теории
# /wiki/Либроком
# /wiki/Служебная:Источники_книг/9785453000111
# /wiki/Грин,_Брайан_Рэндолф
# /wiki/Ткань_космоса:_Пространство,_время_и_текстура_реальности
# /wiki/Либроком
# /wiki/Служебная:Источники_книг/9785397019668
# /wiki/Грин,_Брайан_Рэндолф
# /wiki/Едиториал_УРСС
# /wiki/Служебная:Источники_книг/9785397033336
# /wiki/Каку,_Митио
# /wiki/Служебная:Источники_книг/9785912505201
# /wiki/Рэндалл,_Лиза
# /wiki/Едиториал_УРСС
# /wiki/Служебная:Источники_книг/9785397013710
# /wiki/Сасскинд,_Леонард
# /wiki/Питер_(издательство)
# /wiki/Служебная:Источники_книг/9785496011662
# /wiki/Сасскинд,_Леонард
# /wiki/Питер_(издательство)
# /wiki/Служебная:Источники_книг/9785459018370
# /wiki/Хокинг,_Стивен
# /wiki/Служебная:Источники_книг/5942785643
# /wiki/Яу_Шинтан
# /wiki/Питер_(издательство)
# /wiki/Служебная:Источники_книг/9785459009385
# /wiki/Кобзарев,_Игорь_Юрьевич
# /wiki/Манин,_Юрий_Иванович
# /wiki/Служебная:Источники_книг/5703600286
# /wiki/Служебная:Источники_книг/9780470467244
# /wiki/Барбашов,_Борис_Михайлович
# /wiki/Успехи_физических_наук_(журнал)
# /wiki/1986_год
# /wiki/Белавин,_Александр_Абрамович
# /wiki/Служебная:Источники_книг/5922103032
# /wiki/Симметрия
# /wiki/Инстантон
# /wiki/Магнитный_монополь
# /wiki/Топология
# /wiki/Алгебра_Ли
# /wiki/Новокузнецк
# /wiki/Служебная:Источники_книг/5803233374
# /wiki/Успехи_физических_наук_(журнал)
# /wiki/2005_год
# /wiki/Мир_(издательство)
# /wiki/Служебная:Источники_книг/5030015663
# /wiki/Грин,_Майкл_(физик)
# /wiki/Успехи_физических_наук_(журнал)
# /wiki/1986_год
# /wiki/Успехи_физических_наук_(журнал)
# /wiki/1998_год
# /wiki/Успехи_физических_наук_(журнал)
# /wiki/1998_год
# /wiki/Каку,_Мичио
# /wiki/Мир_(издательство)
# /wiki/Служебная:Источники_книг/5030025189
# /wiki/Служебная:Источники_книг/5020296899
# /wiki/Служебная:Источники_книг/5020296600
# /wiki/Успехи_физических_наук_(журнал)
# /wiki/2002_год
# /wiki/Морозов,_Алексей_Юрьевич
# /wiki/Поляков,_Александр_Маркович
# /wiki/Служебная:Источники_книг/9785354013678
# /wiki/Служебная:Источники_книг/0521860695
# /wiki/ArXiv.org
# /wiki/ArXiv.org
# /wiki/ArXiv.org
# /wiki/ArXiv.org
# /wiki/Служебная:Источники_книг/0679454438
# /wiki/Служебная:Источники_книг/0618551050
# /wiki/Служебная:Источники_книг/0224076051
# /wiki/Служебная:Источники_книг/9780465092758
# /wiki/Портал:Физика
# /wiki/Портал:Физика
# /wiki/Гросс,_Дэвид
# /wiki/Элементы.ру
# /wiki/Популярная_механика
# /wiki/Шаблон:Внешние_ссылки
# /wiki/Нормативный_контроль
# /wiki/Национальная_библиотека_Франции
# /wiki/Gemeinsame_Normdatei
# /wiki/Контрольный_номер_Библиотеки_Конгресса
# /wiki/Microsoft_Academic
# /wiki/Шаблон:Теории_гравитации
# /wiki/Гравитация
# /wiki/Альтернативные_теории_гравитации
# /wiki/Квантовая_гравитация
# /wiki/Единая_теория_поля
# /wiki/Классическая_физика
# /wiki/Классическая_теория_тяготения_Ньютона
# /wiki/Релятивистская_физика
# /wiki/Общая_теория_относительности
# /wiki/Математическая_формулировка_общей_теории_относительности
# /wiki/Гамильтонова_формулировка_общей_теории_относительности
# /wiki/Принцип_эквивалентности_сил_гравитации_и_инерции
# /wiki/Принцип_Маха
# /wiki/Геометродинамика
# /wiki/Теория_гравитации_Лесажа
# /wiki/Модифицированная_ньютоновская_динамика
# /wiki/Релятивистская_теория_гравитации
# /wiki/Калибровочная_теория_гравитации
# /wiki/Гравитация_с_массивным_гравитоном
# /wiki/Телепараллелизм
# /wiki/Теория_Нордстрёма
# /wiki/Теория_Бранса_—_Дикке
# /wiki/Биметрические_теории_гравитации
# /wiki/Несимметричные_теории_гравитации
# /wiki/Теория_гравитации_Уайтхеда
# /wiki/Теория_Эйнштейна_—_Картана
# /wiki/Тетрадная_теория_гравитации
# /wiki/Каноническая_квантовая_гравитация
# /wiki/Петлевая_квантовая_гравитация
# /wiki/Причинная_динамическая_триангуляция
# /wiki/Евклидова_квантовая_гравитация
# /wiki/Общая_теория_относительности_в_многомерном_пространстве
# /wiki/Теория_Калуцы_—_Клейна
# /wiki/Супергравитация
# /wiki/Теория_бозонных_струн
# /wiki/Теория_суперструн
# /wiki/М-теория
# /wiki/Исключительно_простая_теория_всего

# %% [markdown]
# ## Часть 2 (5 баллов)

# %% [markdown]
# Реализуйте заданную функцию.
#
# Под путем подразумевается последовательность ссылок на статьи из **ru.wikipedia.org** (то есть нам не подходит случай, когда страница A из ru.wikipedia.org ссылается на страницу B из en.wikipedia.org, а та, в свою очередь, на страницу C из ru.wikipedia.org).
#
# Проще всего реализовать функцию через поиск в ширину (https://en.wikipedia.org/wiki/Breadth-first_search):
#
# 1. Начинаем из исходной статьи
# 2. Отбираем все статьи, куда она ссылается
# 3. Если есть ссылка на конечную статью - завершаем
# 4. Если нет ссылки на конечную статью - отбираем все статьи, куда они ссылаются **и где мы еще не были**
# 5. Если есть ссылка на конечную статью - завершаем
# 6. Если нет - повторяем до победного
#
# Чтобы вернуть сам путь, а не только его длину, вам нужно хранить отношения между статьями. Придумайте структуру, которая позволит быстро восстанавливать путь.
#
# Запросы к серверу должны выполняться параллельно (максимальное количество одновременно бегущих запросов задаётся параметром `n_threads`). Вы можете использовать любой из доступных инструментов (например, практически везде есть некоторый объект Pool с функцией map):
#
# * threading
# * multiprocessing
# * asyncio
# * gevent
#
#
# При выборе инструмента нужно подумать (https://habr.com/ru/post/421625/). Асинхронные библиотеки и threading показывают высокую производительность при выполнении HTTP-запросов (поскольку эта задача нагружает не процессор, а устройства ввода-вывода, то есть это I/O bound задача). Но после выполнения запросов нужно извлечь ссылки из текстов страниц, а это, вообще-то, достаточно вычислительно сложная задача (все библиотеки для парсинга HTML, по сути, превращают строку с HTML-кодом во внутреннее представление дерева элементов страницы).
#
# Поэтому если вы будете параллелить еще и парсинг HTML (а это происходит внутри функции `links_from_text`, когда мы создаем класс BeautifulSoup), это нужно делать либо с помощью multiprocessing (чтобы задача параллелилась на разные ядра процессора), либо не параллелить вообще и просто доставать ссылки последовательно в один поток.

# %%
def shortest_path(from_article: str, to_article: str, n_threads: int) -> List[str]:
    pass

assert len(shortest_path('Теория_струн', 'Теория_струн', 10)) == 0
assert shortest_path('Теория_струн', 'Теоретическая_физика') == ['Теоретическая_физика'] # не включайте исходную статью в путь
assert len(shortest_path('Теория_струн', 'Партия жуликов и воров', 10)) > 0

# %% [markdown]
# ## Часть 3 (2 балла)
#
# ### Немного про аргументы командой строки
#
# Они позволяют задавать параметры для выполнения программы прямо в терминале. Например, когда вы выполняете команду `git add file.txt`, вы на самом деле вызываете команду `git`, передавая ей **позиционные** аргументы (поскольку порядок их перечисления важен для работы программы) `add` и `file.txt`. **Непозиционные** аргументы передаются, например, так:
#
# `python3 my_script.py --first_arg=123 --second_arg=1111`
#
# причем мы можем поменять их местами при вызове команды и в логике работы программы ничего не изменится:
#
# `python3 my_script.py --second_arg=1111 --first_arg=123`
#
#
# ### Задание
#
# 1. Закройте Jupyter и откройте PyCharm.
# 2. Используйте библиотеку `click` (https://click.palletsprojects.com/en/7.x/), чтобы написать .py-скрипт, принимающий исходную и конечную статью как аргументы командной строки. Пример того, как программа должна вызываться:
#
# `python3 wikidistance.py --to=Теоретическая_физика --from=Теория_струн` (если вы используете непозиционные аргументы)
#
# `python3 wikidistance.py Теория_струн Теоретическая_физика` (если вы используете позиционные аргументы, вы должны перечислять их в определенном порядке)

# %% [markdown]
# ## Часть 4 (2 балла)
#
# Доработайте функцию и программу, чтобы она выводила **все пути** минимальной длины.

# %% [markdown]
# ## Часть 5 (бонусная; +3 балла к итогу)
#
# NB: Если вы выполняете эту часть, то все равно сдайте отдельно программу, полученную на этапе 3 или 4.
#
# Доработайте функцию и программу, чтобы программа принимала на вход путь до JSON-файла с заданием. Пример вызова:
#
# `python3 wikidistance_pro_edition.py ~/path/to/task.json ~/path/to/output.json`
#
# Здесь в файле, который находится по пути `ваша_домашняя_папка/path/to/task.json`, лежит JSON-файл следующего вида:
#
# ```json
# [
# {"from": "Теория_струн", "to": "Теоретическая_физика"},
# {"from": "Теория_всего_(философия)", "to": "Теория_струн"}
# ]
# ```
#
# Программа должна обходить Википедию до тех пор, пока не найдет все кратчайшие маршруты между всеми переданными парами статей. Она должна использовать общую структуру данных для всех пар (чтобы в итоге сделать меньше запросов к серверу, чем если бы мы находили путь для каждой из пар по-отдельности).
#
# Программа должна положить в выходной файл, путь к которому задается параметром командой строки (можно использовать file arguments из click https://click.palletsprojects.com/en/7.x/arguments/), JSON вида:
#
# ```json
# [
# {"from": "Теория_струн", "to": "Теоретическая_физика", "all_shortest_paths": [["a", "b", "Теоретическая_физика"]]},
# {"from": "Теория_всего_(философия)", "to": "Теория_струн", "all_shortest_paths": [["с", "b", "Теория_струн"], ["d", "b", "Теория_струн"]]}
# ]
# ```
#
# Здесь в `all_shortest_paths` лежит список списков строк - все возможные кратчайшие пути.
#
#
# Основной челлендж этой части - аккуратно реализовать работу с представлением графа Википедии.

# %% [markdown]
# ## Дополнительные советы и требования
#
# * PEP8 ¯¯\\\_(ツ)\_/¯¯
# * Предполагается, что исходная и конечная статья существуют (не требуется это явно проверять, но если очень хочется, то можно).
# * Если при загрузке какой-то из страниц возникает ошибка, нужно повторить запрос. Если это происходит слишком часто, возможно, вы DDoS-ите сайт запросами и стоит уменьшить количество потоков.
# * Чтобы объединить несколько итераторов, можно использовать функцию https://docs.python.org/3.8/library/itertools.html#itertools.chain (и вообще в этом модуле есть много всего полезного)
# * При тестировании не используйте слишком далёкие по смыслу статьи - есть вероятность, что вы будете очень долго ждать выполнения программы (http://www.machinelearning.ru/wiki/index.php?title=%D0%9F%D1%80%D0%BE%D0%BA%D0%BB%D1%8F%D1%82%D0%B8%D0%B5_%D1%80%D0%B0%D0%B7%D0%BC%D0%B5%D1%80%D0%BD%D0%BE%D1%81%D1%82%D0%B8)
